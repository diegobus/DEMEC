# %%
import os, glob

graphs_dir = "data/processed/graphs"   # change as needed
files = glob.glob(os.path.join(graphs_dir, "*.gpickle"))
print(f"Found {len(files)} graphs")
print("First few:", files[:5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 import os, glob
#       3 # get root dir
# ----> 4 project_root = os.path.dirname(os.path.dirname(os.path.abspath(__file__)))
#       6 graphs_dir = os.path.join(project_root, "data/processed/graphs_molclr")   # change as needed
#       7 files = glob.glob(os.path.join(graphs_dir, "*.gpickle"))
#
# NameError: name '__file__' is not defined

# %%
from networkx.readwrite import gpickle

gpickle.read_gpickle('data/processed/graphs/100477468.gpickle')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from networkx.readwrite import gpickle
#       3 gpickle.read_gpickle('data/processed/graphs_molclr/100000085.gpickle')
#
# ImportError: cannot import name 'gpickle' from 'networkx.readwrite' (/Users/diegobustamante/miniconda3/envs/demec/lib/python3.11/site-packages/networkx/readwrite/__init__.py)

# %%
import pickle

with open(files[0], "rb") as f:
    g = pickle.load(f)

import networkx as nx
print(type(g), g.number_of_nodes(), g.number_of_edges())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 import pickle
# ----> 3 with open(files[0], "rb") as f:
#       4     g = pickle.load(f)
#       6 import networkx as nx
#
# IndexError: list index out of range

# %%
list(g.nodes(data=True))[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 list(g.nodes(data=True))[:5]
#
# NameError: name 'g' is not defined

# %%
list(g.edges(data=True))[:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 list(g.edges(data=True))[:5]
#
# NameError: name 'g' is not defined

# %%
import pandas as pd
matrix = pd.read_csv('/Users/gm/Library/CloudStorage/OneDrive-Stanford/Academics/2025 Fall/CS 224W/DEMEC/data/processed/cid_se_matrix.csv')
matrix.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 import pandas as pd
# ----> 2 matrix = pd.read_csv('/Users/gm/Library/CloudStorage/OneDrive-Stanford/Academics/2025 Fall/CS 224W/DEMEC/data/processed/cid_se_matrix.csv')
#       3 matrix.shape
#
# ...

# %%
import os, glob

graphs_dir = "data/processed/graphs"   # change as needed
files = glob.glob(os.path.join(graphs_dir, "*.gpickle"))
print(f"Found {len(files)} graphs")
print("First few:", files[:5])
# Out:
# Found 1430 graphs
# First few: ['data/processed/graphs/100477468.gpickle', 'data/processed/graphs/100010340.gpickle', 'data/processed/graphs/100003516.gpickle', 'data/processed/graphs/100004428.gpickle', 'data/processed/graphs/100002995.gpickle']

# %%
from networkx.readwrite import gpickle

gpickle.read_gpickle('data/processed/graphs/100477468.gpickle')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from networkx.readwrite import gpickle
#       3 gpickle.read_gpickle('data/processed/graphs/100477468.gpickle')
#
# ImportError: cannot import name 'gpickle' from 'networkx.readwrite' (/Users/gm/miniconda3/envs/demec/lib/python3.11/site-packages/networkx/readwrite/__init__.py)

# %%
import pickle

with open(files[0], "rb") as f:
    g = pickle.load(f)

import networkx as nx
print(type(g), g.number_of_nodes(), g.number_of_edges())
# Out:
# <class 'networkx.classes.graph.Graph'> 29 30

# %%
list(g.nodes(data=True))[:5]
# Out:
# [(0,
#   {'_atom_str': 'C',
#    '_pos': 0,
#    'element': 'C',
#    'charge': 0,
#    'aromatic': False,
#    'hcount': 3}),
#  (1,
#   {'_atom_str': 'C',
#    '_pos': 1,
#    'element': 'C',
#    'charge': 0,
#    'aromatic': False,
#    'hcount': 2}),
#  (2,
#   {'_atom_str': 'C',
#    '_pos': 2,
#    'element': 'C',
#    'charge': 0,
#    'aromatic': False,
#    'hcount': 2}),
#  (3,
#   {'_atom_str': 'N',
#    '_pos': 3,
#    'element': 'N',
#    'charge': 0,
#    'aromatic': False,
#    'hcount': 1}),
#  (4,
#   {'_atom_str': 'C',
#    '_pos': 4,
#    'element': 'C',
#    'charge': 0,
#    'aromatic': False,
#    'hcount': 0})]

# %%
list(g.edges(data=True))[:5]
# Out:
# [(0, 1, {'_bond_str': '', '_pos': 1, 'order': 1}),
#  (1, 2, {'_bond_str': '', '_pos': 2, 'order': 1}),
#  (2, 3, {'_bond_str': '', '_pos': 3, 'order': 1}),
#  (3, 4, {'_bond_str': '', '_pos': 4, 'order': 1}),
#  (4, 5, {'_bond_str': '=', '_pos': 7, 'order': 2})]

# %%
import pandas as pd
matrix = pd.read_csv('/Users/gm/Library/CloudStorage/OneDrive-Stanford/Academics/2025 Fall/CS 224W/DEMEC/data/processed/cid_se_matrix.csv')
matrix.shape
# Out:
# (1430, 4252)
